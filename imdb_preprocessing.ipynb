# %%
import pandas as pd
import numpy as np
import re
import string
import nltk
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
path = '/content/gdrive/My Drive/imdb_reviews/labeledTrainData.tsv'
df = pd.read_csv(path,sep='\t')

# %%
df.shape
# Out:
# (25000, 3)

# %%
df.head()
# Out:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...

# %%
def remove_html_tags(review): 
    clean = re.compile('<.*?>')
    review = re.sub(clean,'',review)
    return review

# %%
def to_lower_case(review):
    return review.lower()

# %%
def remove_special_char(review):
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    sentence = review.split('.')
    words = []
    for sent in sentence:
        for word in sent.split():
            words.append(word)
    # remove punctuation from each word
    stripped = [re_punc.sub('', w) for w in words]
    review = ' '.join(word for word in stripped)
    return review

# %%
# def lemmatize(review):
#     lemmatizer = nltk.stem.WordNetLemmatizer()
#     review= ' '.join([lemmatizer.lemmatize(word) for word in review.split(' ')])
#     return review

# %%
# def remove_stop_words(review):
#     tokens = nltk.word_tokenize(review)
#     stopword_list = nltk.corpus.stopwords.words('english')
#     filtered_tokens = [token for token in tokens if token not in stopword_list]
#     review = ' '.join(filtered_tokens)
#     return review

# %%
 reviews = df.review
 reviews = reviews.apply(remove_html_tags)
 reviews = reviews.apply(to_lower_case)
 reviews = reviews.apply(remove_special_char)
 df['normalized_reviews'] = reviews
 df.head(10)
# Out:
#         id  ...                                 normalized_reviews
# 0   5814_8  ...  with all this stuff going down at the moment w...
# 1   2381_9  ...  the classic war of the worlds by timothy hines...
# 2   7759_3  ...  the film starts with a manager nicholas bell g...
# 3   3630_4  ...  it must be assumed that those who praised this...
# 4   9495_8  ...  superbly trashy and wondrously unpretentious 8...
# 5   8196_8  ...  i dont know why people think this is such a ba...
# 6   7166_2  ...  this movie could have been very good but comes...
# 7  10633_1  ...  i watched this video at a friends house im gla...
# 8    319_1  ...  a friend of mine bought this film for £1 and e...
# 9  8713_10  ...  this movie is full of references like mad max ...
#
# [10 rows x 4 columns]

# %%
df.review[3]
# Out:
# 'It must be assumed that those who praised this film (\\the greatest filmed opera ever,\\" didn\'t I read somewhere?) either don\'t care for opera, don\'t care for Wagner, or don\'t care about anything except their desire to appear Cultured. Either as a representation of Wagner\'s swan-song, or as a movie, this strikes me as an unmitigated disaster, with a leaden reading of the score matched to a tricksy, lugubrious realisation of the text.<br /><br />It\'s questionable that people with ideas as to what an opera (or, for that matter, a play, especially one by Shakespeare) is \\"about\\" should be allowed anywhere near a theatre or film studio; Syberberg, very fashionably, but without the smallest justification from Wagner\'s text, decided that Parsifal is \\"about\\" bisexual integration, so that the title character, in the latter stages, transmutes into a kind of beatnik babe, though one who continues to sing high tenor -- few if any of the actors in the film are the singers, and we
# ...

# %%
df.normalized_reviews[3]
# Out:
# 'it must be assumed that those who praised this film the greatest filmed opera ever didnt i read somewhere either dont care for opera dont care for wagner or dont care about anything except their desire to appear cultured either as a representation of wagners swansong or as a movie this strikes me as an unmitigated disaster with a leaden reading of the score matched to a tricksy lugubrious realisation of the text its questionable that people with ideas as to what an opera or for that matter a play especially one by shakespeare is about should be allowed anywhere near a theatre or film studio syberberg very fashionably but without the smallest justification from wagners text decided that parsifal is about bisexual integration so that the title character in the latter stages transmutes into a kind of beatnik babe though one who continues to sing high tenor  few if any of the actors in the film are the singers and we get a double dose of armin jordan the conductor who is seen as the fac
# ...

# %%
# df.to_csv("preprocessed_imdbTrain.tsv", sep="\t")
